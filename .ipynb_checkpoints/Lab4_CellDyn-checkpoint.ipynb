# %%
import Bio
import numpy as np
import math, random
import matplotlib.pyplot as plt

# %% [markdown]
# Task 1 Begin
# -------

# %%
kp = 0.1
km = 0.3
random.seed(3)

To = 1/km
Tc = 1/kp

r = random.random()
start=0.5
if r<0.5:
    start=0
else:
    start=1

current = start
dt = 1
for t in range(100):
    Q = np.array([[1-(kp*dt), (km*dt)],[(kp*dt), 1-(km*dt)]])
    if current==0:
        y = random.random()
        if y<Q[0][1]:
            current = 1
            print("Open->Closed@ "+str(t))
            dt = 0
    else:
        x = random.random()
        if x<Q[1][0]:
            current = 0
            print("Closed->Open@ "+str(t))
            dt = 0
    dt += 1
# Out:
# Open->Closed@ 1
# Closed->Open@ 4
# Open->Closed@ 5
# Closed->Open@ 8
# Open->Closed@ 10
# Closed->Open@ 14
# Open->Closed@ 17
# Closed->Open@ 20
# Open->Closed@ 22
# Closed->Open@ 24
# Open->Closed@ 26
# Closed->Open@ 31
# Open->Closed@ 33
# Closed->Open@ 36
# Open->Closed@ 37
# Closed->Open@ 42
# Open->Closed@ 44
# Closed->Open@ 53
# Open->Closed@ 54
# Closed->Open@ 60
# Open->Closed@ 62
# Closed->Open@ 64
# Open->Closed@ 67
# Closed->Open@ 70
# Open->Closed@ 71
# Closed->Open@ 74
# Open->Closed@ 76
# Closed->Open@ 83
# Open->Closed@ 84
# Closed->Open@ 86
# Open->Closed@ 87
# Closed->Open@ 90
# Open->Closed@ 91
# Closed->Open@ 96
# Open->Closed@ 98

# %%
print(Q)
# Out:
# [[0.9 0.3]
#  [0.1 0.7]]

# %%
currents = start
t = 1
while t<=100:
    rtwo = random.random()
    TC = (1/kp) *np.log(1/rtwo)
    TO = (1/km) *np.log(1/rtwo)
    if currents==0:
        print("op>clo @ "+str(t+TO))
        t += TO
        currents = 1
    else:
        print("clo>op @ "+str(t+TC))
        t += TC
        currents = 0
# Out:
# op>clo @ 2.727005441661672
# clo>op @ 8.53839442883585
# op>clo @ 10.13116902006394
# clo>op @ 10.743316140038381
# op>clo @ 13.00728742463204
# clo>op @ 21.41931590560656
# op>clo @ 22.512888791405924
# clo>op @ 36.88305668297833
# op>clo @ 40.88424495142404
# clo>op @ 41.108773684625554
# op>clo @ 43.28131015847655
# clo>op @ 49.288257912690206
# op>clo @ 64.1852976850237
# clo>op @ 72.97499803120695
# op>clo @ 74.7909552093812
# clo>op @ 113.8847750171413

# %% [markdown]
# Task 2 Begin
# -------

# %%
Mextra = 1.2 #extracellular
Mmax = 1000
M = 0
km = 5 #ratecon
t = 0
Mt = 0 #startVal
kpl = 0.1 #k+
kmi = 0.3 #k-
a1 = kpl #propensity open
a2 = kmi #propensity close
a3 = km*Mextra #propensity pass ion >>> 0 if closed
currents = 1
ooo = []
ccc = []
ppp = []
ttt = []
nnn = []
while M<Mmax:
    r1 = random.random()
    r2 = random.random()
    if currents == 0:
        a0 = a1+a2+a3
    else:
        a0 = a1+a2
    tau = (1/a0)*np.log(1/r1)
    if currents == 0:
        if r2>=(1/a0)*a1 and r2<(1/a0)*(a1+a2):
            #print("reaction closing")
            ccc.append([t,M])
            nnn.append([t,M,1])
            currents = 1
        elif r2>=(1/a0)*(a1+a2):
            #print("reaction ion passing")
            M = M+1
            ppp.append([t,M])
            nnn.append([t,M,2])
    else:
        if r2<(1/a0)*a1:
            #print("reaction opening")
            ooo.append([t,M])
            nnn.append([t,M,0])
            currents = 0
    ttt.append([t,M])
    t=t+tau
#print(ppp[:500])

# %%
nnn = np.asarray(nnn)
fig = plt.figure(figsize=(15,15))
for vtx in range(len(nnn)-1):
    if nnn[vtx,1]==500:
        break
    if nnn[vtx,2]==0:
        plt.plot([nnn[vtx,0],nnn[vtx+1,0]],[nnn[vtx,1],nnn[vtx+1,1]], c='red')
    elif nnn[vtx,2]==1:
        plt.plot([nnn[vtx,0],nnn[vtx+1,0]],[nnn[vtx,1],nnn[vtx+1,1]], c='blue')
    else:
        plt.plot([nnn[vtx,0],nnn[vtx+1,0]],[nnn[vtx,1],nnn[vtx+1,1]], c='green')

# %% [markdown]
# Task 3 Begin
# -------------

# %%
fivehundo = np.asarray(ppp)[:500,0]
#D in cm2/sec
D = 0.000005

e = np.random.normal(0,1,2)
print(e)

X = np.zeros(500)
Y = np.zeros(500)

X[0] = np.sqrt(2*D)*e[0]
Y[0] = abs(np.sqrt(2*D)*e[1])
e = np.random.normal(0,1,2)
X[1] = X[0] + np.sqrt(2*D)*e[0]
Y[1] = abs(Y[0] + np.sqrt(2*D)*e[1])

fig = plt.figure(figsize = (15,15))

for t in range(1,499):
    e = np.random.normal(0,1,2)
    dt = fivehundo[t]-fivehundo[t-1]
    X[t+1] = X[t] + np.sqrt(2*D*dt)*e[0]
    Y[t+1] = abs(Y[t] + np.sqrt(2*D*dt)*e[1])
plt.scatter(X,Y)
plt.plot([np.average(X),np.average(X)],[0,max(Y)], c='pink')
plt.plot([min(X),max(X)],[0,0], c='cyan')
    

#cell boundaries in micrometres
yb = 0
yt = 100
xl = -50
xr = 50
# Out:
# [-0.93425    -0.08840452]

# %%
X = np.zeros(500)
Y = np.zeros(500)
nX = np.zeros(500)
nY = np.zeros(500)
fig = plt.figure(figsize=(20,20))
for its in range(499,-1,-1):
    #print(its)
    for cell in range(0,2):
        e = np.random.normal(0,1,2)
        dt = fivehundo[t]-fivehundo[t-1]
        if its==499:
            nX[cell] = np.sqrt(2*D)*e[0]
            nY[cell] = abs(np.sqrt(2*D)*e[1])
        else:
            nX[cell] = X[cell] + np.sqrt(2*D*dt)*e[0]
            nY[cell] = abs(Y[cell] + np.sqrt(2*D)*e[1])
            plt.plot([X[cell],nX[cell]],[Y[cell],nY[cell]])
        X[cell] = nX[cell]
        Y[cell] = nY[cell]
plt.show()
